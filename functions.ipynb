# %% [markdown]
# #Functions

# %% [markdown]
# 1. what is the difference between a function and a method in python?
#   - a function is independent
#
# 2. second question
#   -  tt

# %%
#question
...
this is answer
...
